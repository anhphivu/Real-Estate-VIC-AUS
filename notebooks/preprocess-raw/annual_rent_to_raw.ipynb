# %% [markdown]
# # Annual rent preprocess
#
# Preprocess the annual rent data to raw

# %%
import pandas as pd
import os

# %%
def reshape_rent_data(filepath, sheet_name):
    # Load data for the specified sheet
    df = pd.read_excel(filepath, sheet_name=sheet_name)
    
    # Extract the suburb names from the dataset
    suburbs = df['Unnamed: 1'].dropna().tolist()[1:]
    
    # Initialize an empty DataFrame to store the reshaped data
    reshaped_data = pd.DataFrame()
    reshaped_data['Suburb'] = suburbs

    # Iterate through columns to extract month/year and corresponding Count and Median
    for i in range(2, df.shape[1], 2):
        month_year = df.iloc[0, i]
        
        # Extract count and median values for the suburbs
        count_values = df.iloc[2:, i].tolist()[1:]
        median_values = df.iloc[2:, i+1].tolist()[1:]
        
        # Add the count and median values to the reshaped DataFrame
        reshaped_data[f'{month_year} Count'] = count_values
        reshaped_data[f'{month_year} Median'] = median_values

    return reshaped_data

# %%
def save_to_csv(df, output_folder, filename):
    # Ensure the output folder exists, if not, create it
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Construct the full path for the output CSV file
    output_path = os.path.join(output_folder, filename)
    
    # Save the DataFrame to the CSV file
    df.to_csv(output_path, index=False)
    return output_path

# %%
# "1 bedroom flat" sheet
df_1_bed_flat = reshape_rent_data("../../data/landing/moving_annual_rent.xlsx", "1 bedroom flat")
df_1_bed_flat.head()
# Out:
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
#                    Suburb Mar 2000 Count Mar 2000 Median Jun 2000 Count  \
# 0                Armadale            210             150            212
# 1           Carlton North             87             150             78
# 2       Carlton-Parkville            303             165            300
# 3         CBD-St Kilda Rd            755             250            861
# 4  Collingwood-Abbotsford            130             135            127
#
#   Jun 2000 Median Sep 2000 Count Sep 2000 Median Dec 2000 Count  \
# 0             150            213             155            213
# 1             155             74             150             65
# 2             170            315             175            351
# 3             250            934             250            952
# 4             145            157             160            166
#
#   Dec 2000 Median Mar 2001 Count  ... Mar 2022 Count Mar 2022 Median  \
# 0             160            206  ...            223             310
# 1             150             73  ...             79             300
# 2             180            360  ...           3516             259
# 3             250           1145  ...           8769             320
# 4             165            202  ...            911             360
#
#   Jun 2022 Count Jun 2022 Median Sep 2022 Count Sep 2022 Median  \
# 0            233             320            237             340
# 1             68             320             72             320
# 2           3544             269           4296             300
# 3           8619             340           9913             365
# 4            890             370           1000             383
#
#   Dec 2022 Count Dec 2022 Median Mar 2023 Count Mar 2023 Median
# 0            238             350            204             360
# 1             71             330             64             373
# 2           4203             309           4488             352
# 3           9638             390           9781             430
# 4            946             400            855             420
#
# [5 rows x 185 columns]

# %%
# 2 bedroom flat sheet
df_2_bed_flat = reshape_rent_data("../../data/landing/moving_annual_rent.xlsx", "2 bedroom flat")
df_2_bed_flat.head()
# Out:
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
#                    Suburb Mar 2000 Count Mar 2000 Median Jun 2000 Count  \
# 0                Armadale            333             200            335
# 1           Carlton North            117             215            123
# 2       Carlton-Parkville            476             270            480
# 3         CBD-St Kilda Rd            999             340           1032
# 4  Collingwood-Abbotsford            119             210            132
#
#   Jun 2000 Median Sep 2000 Count Sep 2000 Median Dec 2000 Count  \
# 0             205            338             210            339
# 1             220            130             220            123
# 2             270            485             270            485
# 3             343           1079             350           1077
# 4             248            138             248            143
#
#   Dec 2000 Median Mar 2001 Count  ... Mar 2022 Count Mar 2022 Median  \
# 0             210            324  ...            379             425
# 1             220            136  ...            124             430
# 2             270            462  ...           2105             395
# 3             350           1119  ...           8171             420
# 4             270            167  ...            999             480
#
#   Jun 2022 Count Jun 2022 Median Sep 2022 Count Sep 2022 Median  \
# 0            407             450            400             450
# 1            113             450            111             455
# 2           1936             400           1991             440
# 3           7346             450           7557             500
# 4            965             500           1062             520
#
#   Dec 2022 Count Dec 2022 Median Mar 2023 Count Mar 2023 Median
# 0            396             468            354             485
# 1            110             465             96             480
# 2           1853             470           1624             530
# 3           7238             550           6921             600
# 4           1001             540            908             565
#
# [5 rows x 185 columns]

# %%
# 3 bedroom flat
df_3_bed_flat = reshape_rent_data("../../data/landing/moving_annual_rent.xlsx", "3 bedroom flat")
df_3_bed_flat.head()
# Out:
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
#                    Suburb Mar 2000 Count Mar 2000 Median Jun 2000 Count  \
# 0                Armadale             26             305             25
# 1           Carlton North             30             293             26
# 2       Carlton-Parkville             83             310             70
# 3         CBD-St Kilda Rd            323             475            318
# 4  Collingwood-Abbotsford             26             350             21
#
#   Jun 2000 Median Sep 2000 Count Sep 2000 Median Dec 2000 Count  \
# 0             310             22             300             23
# 1             298             20             300             23
# 2             303             71             305             65
# 3             460            291             460            272
# 4             350             23             350             19
#
#   Dec 2000 Median Mar 2001 Count  ... Mar 2022 Count Mar 2022 Median  \
# 0             300             26  ...             67             720
# 1             300             16  ...             29             620
# 2             330             62  ...            191             585
# 3             458            267  ...            854             650
# 4             375             15  ...             98             780
#
#   Jun 2022 Count Jun 2022 Median Sep 2022 Count Sep 2022 Median  \
# 0             73             700             71             720
# 1             21             660             21             620
# 2            185             590            197             590
# 3            775             680            773             750
# 4            103             785            116             800
#
#   Dec 2022 Count Dec 2022 Median Mar 2023 Count Mar 2023 Median
# 0             70             670             56             685
# 1             21             660             15             650
# 2            193             600            159             650
# 3            720             800            689             900
# 4            105             800            105             810
#
# [5 rows x 185 columns]

# %%
# 2 bedroom house
df_2_bed_house = reshape_rent_data("../../data/landing/moving_annual_rent.xlsx", "2 bedroom house")
df_2_bed_house.head()
# Out:
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
#                    Suburb Mar 2000 Count Mar 2000 Median Jun 2000 Count  \
# 0                Armadale             66             290             70
# 1           Carlton North            204             250            217
# 2       Carlton-Parkville            109             250            112
# 3         CBD-St Kilda Rd              -               -              -
# 4  Collingwood-Abbotsford            158             235            153
#
#   Jun 2000 Median Sep 2000 Count Sep 2000 Median Dec 2000 Count  \
# 0             290             64             298             62
# 1             260            221             260            200
# 2             253             91             250             96
# 3               -              -               -              -
# 4             235            155             240            144
#
#   Dec 2000 Median Mar 2001 Count  ... Mar 2022 Count Mar 2022 Median  \
# 0             300             61  ...             36             663
# 1             260            187  ...            116             597
# 2             250            113  ...             70             560
# 3               -              -  ...              -               -
# 4             248            144  ...            148             601
#
#   Jun 2022 Count Jun 2022 Median Sep 2022 Count Sep 2022 Median  \
# 0             39             675             42             663
# 1            130             600            136             605
# 2             82             550             78             550
# 3              -               -              -               -
# 4            160             600            155             600
#
#   Dec 2022 Count Dec 2022 Median Mar 2023 Count Mar 2023 Median
# 0             42             673             43             675
# 1            150             618            138             633
# 2             79             560             81             580
# 3              -               -              -               -
# 4            147             600            135             620
#
# [5 rows x 185 columns]

# %%
# 3 bedroom house
df_3_bed_house = reshape_rent_data("../../data/landing/moving_annual_rent.xlsx", "3 bedroom house")
df_3_bed_house.head()
# Out:
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
#                    Suburb Mar 2000 Count Mar 2000 Median Jun 2000 Count  \
# 0                Armadale             44             373             45
# 1           Carlton North            146             300            135
# 2       Carlton-Parkville            106             320            111
# 3         CBD-St Kilda Rd              -               -              -
# 4  Collingwood-Abbotsford             99             270             97
#
#   Jun 2000 Median Sep 2000 Count Sep 2000 Median Dec 2000 Count  \
# 0             395             51             415             57
# 1             300            135             310            124
# 2             320            111             320            110
# 3               -              -               -              -
# 4             270            100             283            111
#
#   Dec 2000 Median Mar 2001 Count  ... Mar 2022 Count Mar 2022 Median  \
# 0             395             53  ...             55             950
# 1             310            118  ...            105             760
# 2             325             86  ...             65             760
# 3               -              -  ...              -               -
# 4             285            110  ...            100             788
#
#   Jun 2022 Count Jun 2022 Median Sep 2022 Count Sep 2022 Median  \
# 0             56             865             61             850
# 1             94             750             99             770
# 2             74             773             76             785
# 3              -               -              -               -
# 4             93             795             93             785
#
#   Dec 2022 Count Dec 2022 Median Mar 2023 Count Mar 2023 Median
# 0             57             950             54             973
# 1            105             780             97             780
# 2             89             770             94             783
# 3              -               -              -               -
# 4             91             790             88             790
#
# [5 rows x 185 columns]

# %%
# 4 bedroom house
df_4_bed_house = reshape_rent_data("../../data/landing/moving_annual_rent.xlsx", "4 bedroom house")
df_4_bed_house.head()
# Out:
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
#                    Suburb Mar 2000 Count Mar 2000 Median Jun 2000 Count  \
# 0                Armadale             11             580             12
# 1           Carlton North             78             380             78
# 2       Carlton-Parkville             37             420             32
# 3         CBD-St Kilda Rd              -               -              -
# 4  Collingwood-Abbotsford             15             310             13
#
#   Jun 2000 Median Sep 2000 Count Sep 2000 Median Dec 2000 Count  \
# 0             673             14             773             14
# 1             380             76             380             70
# 2             420             46             420             49
# 3               -              -               -              -
# 4             320             15             330             14
#
#   Dec 2000 Median Mar 2001 Count  ... Mar 2022 Count Mar 2022 Median  \
# 0             673             15  ...             14            1100
# 1             380             50  ...             18            1025
# 2             420             44  ...             41             930
# 3               -              -  ...              -               -
# 4             345             14  ...             12             875
#
#   Jun 2022 Count Jun 2022 Median Sep 2022 Count Sep 2022 Median  \
# 0             17            1100             17            1150
# 1             21            1100             23            1050
# 2             45             930             46             920
# 3              -               -              -               -
# 4             15             950             15            1000
#
#   Dec 2022 Count Dec 2022 Median Mar 2023 Count Mar 2023 Median
# 0             19            1200             24            1200
# 1             28            1015             28            1100
# 2             42             945             42            1000
# 3              -               -              -               -
# 4             16             998             17            1010
#
# [5 rows x 185 columns]

# %%
# All properties
df_all = reshape_rent_data("../../data/landing/moving_annual_rent.xlsx", "All properties")
df_all.head()
# Out:
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
# /tmp/ipykernel_553478/868455095.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Count'] = count_values
# /tmp/ipykernel_553478/868455095.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   reshaped_data[f'{month_year} Median'] = median_values
#                    Suburb Mar 2000 Count Mar 2000 Median  Jun 2000 Count  \
# 0                Armadale            733             200             737
# 1           Carlton North            864             260             814
# 2       Carlton-Parkville           1339             260            1304
# 3         CBD-St Kilda Rd           2132             320            2264
# 4  Collingwood-Abbotsford            652             230             653
#
#    Jun 2000 Median Sep 2000 Count Sep 2000 Median Dec 2000 Count  \
# 0              200            738             205            739
# 1              260            799             265            736
# 2              260           1300             260           1320
# 3              320           2358             320           2361
# 4              230            700             240            709
#
#   Dec 2000 Median Mar 2001 Count  ... Mar 2022 Count Mar 2022 Median  \
# 0             210            718  ...            805             430
# 1             270            718  ...            581             580
# 2             260           1273  ...           6143             310
# 3             320           2591  ...          17845             365
# 4             240            746  ...           2353             430
#
#   Jun 2022 Count Jun 2022 Median Sep 2022 Count Sep 2022 Median  \
# 0            851             450            852             450
# 1            535             595            547             600
# 2           6018             319           6871             340
# 3          16792             390          18284             419
# 4           2307             450           2517             480
#
#   Dec 2022 Count  Dec 2022 Median  Mar 2023 Count  Mar 2023 Median
# 0            840              460             751              490
# 1            546              600             490              620
# 2           6627              350            6690              400
# 3          17627              450           17426              500
# 4           2365              495            2163              520
#
# [5 rows x 185 columns]

# %%
# save to raw
one_bedroom_flat = save_to_csv(df_1_bed_flat, "../../data/raw/annual_rent", "1_bedroom_flat_annual_rent.csv")
two_bedroom_flat = save_to_csv(df_2_bed_flat, "../../data/raw/annual_rent", "2_bedroom_flat_annual_rent.csv")
three_bedroom_flat = save_to_csv(df_3_bed_flat, "../../data/raw/annual_rent", "3_bedroom_flat_annual_rent.csv")
two_bed_house = save_to_csv(df_2_bed_house, "../../data/raw/annual_rent", "2_bedroom_house_annual_rent.csv")
three_bed_house = save_to_csv(df_3_bed_house, "../../data/raw/annual_rent", "3_bedroom_house_annual_rent.csv")
four_bed_house = save_to_csv(df_4_bed_house, "../../data/raw/annual_rent", "4_bedroom_house_annual_rent.csv")
all_properties = save_to_csv(df_all, "../../data/raw/annual_rent", "all_properties_annual_rent.csv")
